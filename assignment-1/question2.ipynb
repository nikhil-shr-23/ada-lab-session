# %%
#QUESTION-2
import time
import random
import matplotlib.pyplot as plt
from memory_profiler import memory_usage


def linear_search(a, k):
    for x in a:
        if x == k:
            return True
    return False

def binary_search(a, k):
    l, r = 0, len(a) - 1
    while l <= r:
        m = (l + r) // 2
        if a[m] == k:
            return True
        elif a[m] < k:
            l = m + 1
        else:
            r = m - 1
    return False




def linear_wrap(a, k): linear_search(a, k)
def binary_wrap(a, k): binary_search(a, k)



sizes = [100, 500, 1000, 5000]

# Time lists
lb, la, lw = [], [], []
bb, ba, bw = [], [], []

# Memory lists
mlb, mla, mlw = [], [], []
mbb, mba, mbw = [], [], []



for n in sizes:
    a = sorted(random.sample(range(n * 10), n))

    best = a[0]
    avg = a[n // 2]
    worst = -1

    
    s = time.perf_counter()
    linear_search(a, best)
    lb.append(time.perf_counter() - s)
    mem = memory_usage((linear_wrap, (a, best)))
    mlb.append(max(mem) - min(mem))

    s = time.perf_counter()
    linear_search(a, avg)
    la.append(time.perf_counter() - s)
    mem = memory_usage((linear_wrap, (a, avg)))
    mla.append(max(mem) - min(mem))

    s = time.perf_counter()
    linear_search(a, worst)
    lw.append(time.perf_counter() - s)
    mem = memory_usage((linear_wrap, (a, worst)))
    mlw.append(max(mem) - min(mem))


    s = time.perf_counter()
    binary_search(a, best)
    bb.append(time.perf_counter() - s)
    mem = memory_usage((binary_wrap, (a, best)))
    mbb.append(max(mem) - min(mem))

    s = time.perf_counter()
    binary_search(a, avg)
    ba.append(time.perf_counter() - s)
    mem = memory_usage((binary_wrap, (a, avg)))
    mba.append(max(mem) - min(mem))

    s = time.perf_counter()
    binary_search(a, worst)
    bw.append(time.perf_counter() - s)
    mem = memory_usage((binary_wrap, (a, worst)))
    mbw.append(max(mem) - min(mem))


plt.figure()
plt.plot(sizes, lb, marker='o', label='Best')
plt.plot(sizes, la, marker='o', label='Average')
plt.plot(sizes, lw, marker='o', label='Worst')
plt.xlabel("Input Size")
plt.ylabel("Time (seconds)")
plt.title("Linear Search – Time Complexity")
plt.legend()
plt.show()

plt.figure()
plt.plot(sizes, bb, marker='o', label='Best')
plt.plot(sizes, ba, marker='o', label='Average')
plt.plot(sizes, bw, marker='o', label='Worst')
plt.xlabel("Input Size")
plt.ylabel("Time (seconds)")
plt.title("Binary Search – Time Complexity")
plt.legend()
plt.show()



plt.figure()
plt.plot(sizes, mlb, marker='o', label='Best')
plt.plot(sizes, mla, marker='o', label='Average')
plt.plot(sizes, mlw, marker='o', label='Worst')
plt.xlabel("Input Size")
plt.ylabel("Memory Used (MiB)")
plt.title("Linear Search – Space Complexity")
plt.legend()
plt.show()

plt.figure()
plt.plot(sizes, mbb, marker='o', label='Best')
plt.plot(sizes, mba, marker='o', label='Average')
plt.plot(sizes, mbw, marker='o', label='Worst')
plt.xlabel("Input Size")
plt.ylabel("Memory Used (MiB)")
plt.title("Binary Search – Space Complexity")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 #QUESTION-2
#       2 import time
#       3 import random
# ----> 4 import matplotlib.pyplot as plt
#       5 from memory_profiler import memory_usage
#       6
#       7
#
# ModuleNotFoundError: No module named 'matplotlib'
